# %%
import pandas as pd
import seaborn as sb

# %%
dataset = pd.read_csv("winequality-white_ruba.csv")

dataset = dataset.drop(columns=['fixed acidity','total sulfur dioxide', 'citric acid', 'density'])

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
nd = scaler.fit_transform(dataset)
nd = pd.DataFrame(nd, columns = dataset.columns)

nd
# Out:
#       volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0             0.186275        0.308282   0.106825             0.149826
# 1             0.215686        0.015337   0.118694             0.041812
# 2             0.196078        0.096626   0.121662             0.097561
# 3             0.147059        0.121166   0.145401             0.156794
# 4             0.147059        0.121166   0.145401             0.156794
# ...                ...             ...        ...                  ...
# 4893          0.127451        0.015337   0.089021             0.076655
# 4894          0.235294        0.113497   0.112760             0.191638
# 4895          0.156863        0.009202   0.094955             0.097561
# 4896          0.205882        0.007669   0.038576             0.062718
# 4897          0.127451        0.003067   0.032641             0.069686
#
#             pH  sulphates   alcohol   quality  qual
# 0     0.254545   0.267442  0.129032  0.500000   0.0
# 1     0.527273   0.313953  0.241935  0.500000   0.0
# 2     0.490909   0.255814  0.338710  0.500000   0.0
# 3     0.427273   0.209302  0.306452  0.500000   0.0
# 4     0.427273   0.209302  0.306452  0.500000   0.0
# ...        ...        ...       ...       ...   ...
# 4893  0.500000   0.325581  0.516129  0.500000   0.0
# 4894  0.390909   0.279070  0.258065  0.333333   0.0
# 4895  0.245455   0.279070  0.225806  0.500000   0.0
# 4896  0.563636   0.186047  0.774194  0.666667   1.0
# 4897  0.490909   0.116279  0.612903  0.500000   0.0
#
# [4898 rows x 9 columns]

# %%
X = nd.iloc[: , :8]

Y = nd.iloc[: , 8]

X
# Out:
#       volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0             0.186275        0.308282   0.106825             0.149826
# 1             0.215686        0.015337   0.118694             0.041812
# 2             0.196078        0.096626   0.121662             0.097561
# 3             0.147059        0.121166   0.145401             0.156794
# 4             0.147059        0.121166   0.145401             0.156794
# ...                ...             ...        ...                  ...
# 4893          0.127451        0.015337   0.089021             0.076655
# 4894          0.235294        0.113497   0.112760             0.191638
# 4895          0.156863        0.009202   0.094955             0.097561
# 4896          0.205882        0.007669   0.038576             0.062718
# 4897          0.127451        0.003067   0.032641             0.069686
#
#             pH  sulphates   alcohol   quality
# 0     0.254545   0.267442  0.129032  0.500000
# 1     0.527273   0.313953  0.241935  0.500000
# 2     0.490909   0.255814  0.338710  0.500000
# 3     0.427273   0.209302  0.306452  0.500000
# 4     0.427273   0.209302  0.306452  0.500000
# ...        ...        ...       ...       ...
# 4893  0.500000   0.325581  0.516129  0.500000
# 4894  0.390909   0.279070  0.258065  0.333333
# 4895  0.245455   0.279070  0.225806  0.500000
# 4896  0.563636   0.186047  0.774194  0.666667
# 4897  0.490909   0.116279  0.612903  0.500000
#
# [4898 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify=Y) #large amount of values 50% split

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
prediction = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, prediction))
print(confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       768
#          1.0       1.00      1.00      1.00       212
#
#     accuracy                           1.00       980
#    macro avg       1.00      1.00      1.00       980
# weighted avg       1.00      1.00      1.00       980
#
# [[768   0]
#  [  0 212]]
